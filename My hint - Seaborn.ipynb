# %% [markdown]
# # My hint: Seaborn palettes and colors

# %% [markdown]
# Эта тетрадь - подсказка при работе с Seaborn. Здесь можно посмотреть, какие палитры и цвета бывают, и выбрать что-то подходящее для конкретных проектов и графиков.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#List-of-available-palettes-in-Seaborn" data-toc-modified-id="List-of-available-palettes-in-Seaborn-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>List of available palettes in Seaborn</a></span></li><li><span><a href="#Palettes:-5-colors" data-toc-modified-id="Palettes:-5-colors-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Palettes: 5 colors</a></span></li><li><span><a href="#Palettes:-20-colors" data-toc-modified-id="Palettes:-20-colors-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Palettes: 20 colors</a></span><ul class="toc-item"><li><span><a href="#Diverging-(расходящиеся)" data-toc-modified-id="Diverging-(расходящиеся)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Diverging (расходящиеся)</a></span></li><li><span><a href="#Sequential-(последовательные)" data-toc-modified-id="Sequential-(последовательные)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Sequential (последовательные)</a></span></li><li><span><a href="#Qualitative-(категориальные)" data-toc-modified-id="Qualitative-(категориальные)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Qualitative (категориальные)</a></span></li></ul></li><li><span><a href="#How-to-extract-individual-colors" data-toc-modified-id="How-to-extract-individual-colors-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>How to extract individual colors</a></span></li><li><span><a href="#Types-of-palettes" data-toc-modified-id="Types-of-palettes-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Types of palettes</a></span><ul class="toc-item"><li><span><a href="#hls_palette-&amp;-husl_palette" data-toc-modified-id="hls_palette-&amp;-husl_palette-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>hls_palette &amp; husl_palette</a></span></li><li><span><a href="#cubehelix_palette" data-toc-modified-id="cubehelix_palette-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>cubehelix_palette</a></span></li><li><span><a href="#ColorBrewer" data-toc-modified-id="ColorBrewer-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>ColorBrewer</a></span></li></ul></li><li><span><a href="#Separate-colors-and-their-names-in-Seaborn" data-toc-modified-id="Separate-colors-and-their-names-in-Seaborn-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Separate colors and their names in Seaborn</a></span></li><li><span><a href="#Types-of-charts" data-toc-modified-id="Types-of-charts-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Types of charts</a></span></li></ul></div>

# %% [markdown]
# ## List of available palettes in Seaborn

# %%
import seaborn as sns

# %% [markdown]
# [Deep Dive into Seaborn: Color Palettes](https://medium.com/analytics-vidhya/deep-dive-into-seaborn-palettes-7b5fae5a258e "Deep Dive into Seaborn: Color Palettes")

# %% [markdown]
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %% [markdown]
# ## Palettes: 5 colors

# %% [markdown]
# Здесь расположены все доступные палитры в алфавитном порядке. Все палитры представлены только в прямом расположении (например, 'Accent'; а 'Accent_r' - это та же самая палитра, но перевёрнутая, где цвета идут в обратном порядке, и эти варианты здесь отдельно не представлены).

# %%
sns.palplot(sns.color_palette("Accent", 5))

# %%
sns.palplot(sns.color_palette("Blues", 5))

# %%
sns.palplot(sns.color_palette("BrBG", 5))

# %%
sns.palplot(sns.color_palette("BuGn", 5))

# %%
sns.palplot(sns.color_palette("BuPu", 5))

# %%
sns.palplot(sns.color_palette("CMRmap", 5))

# %%
sns.palplot(sns.color_palette("Dark2", 5))

# %%
sns.palplot(sns.color_palette("GnBu", 5))

# %%
sns.palplot(sns.color_palette("Greens", 5))

# %%
sns.palplot(sns.color_palette("Greys", 5))

# %%
sns.palplot(sns.color_palette("OrRd", 5))

# %%
sns.palplot(sns.color_palette("Oranges", 5))

# %%
sns.palplot(sns.color_palette("PRGn", 5))

# %%
sns.palplot(sns.color_palette("Paired", 5))

# %%
sns.palplot(sns.color_palette("Pastel1", 5))

# %%
sns.palplot(sns.color_palette("Pastel2", 5))

# %%
sns.palplot(sns.color_palette("PiYG", 5))

# %%
sns.palplot(sns.color_palette("PuBu", 5))

# %%
sns.palplot(sns.color_palette("PuBuGn", 5))

# %%
sns.palplot(sns.color_palette("PuOr", 5))

# %%
sns.palplot(sns.color_palette("PuRd", 5))

# %%
sns.palplot(sns.color_palette("Purples", 5))

# %%
sns.palplot(sns.color_palette("RdBu", 5))

# %%
sns.palplot(sns.color_palette("RdGy", 5))

# %%
sns.palplot(sns.color_palette("RdPu", 5))

# %%
sns.palplot(sns.color_palette("RdYlBu", 5))

# %%
sns.palplot(sns.color_palette("RdYlGn", 5))

# %%
sns.palplot(sns.color_palette("Reds", 5))

# %%
sns.palplot(sns.color_palette("Set1", 5))

# %%
sns.palplot(sns.color_palette("Set2", 5))

# %%
sns.palplot(sns.color_palette("Set3", 5))

# %%
sns.palplot(sns.color_palette("Spectral", 5))

# %%
sns.palplot(sns.color_palette("Wistia", 5))

# %%
sns.palplot(sns.color_palette("YlGn", 5))

# %%
sns.palplot(sns.color_palette("YlGnBu", 5))

# %%
sns.palplot(sns.color_palette("YlOrBr", 5))

# %%
sns.palplot(sns.color_palette("YlOrRd", 5))

# %%
sns.palplot(sns.color_palette("afmhot", 5))

# %%
sns.palplot(sns.color_palette("autumn", 5))

# %%
sns.palplot(sns.color_palette("binary", 5))

# %%
sns.palplot(sns.color_palette("bone", 5))

# %%
sns.palplot(sns.color_palette("brg", 5))

# %%
sns.palplot(sns.color_palette("bwr", 5))

# %%
sns.palplot(sns.color_palette("cividis", 5))

# %%
sns.palplot(sns.color_palette("cool", 5))

# %%
sns.palplot(sns.color_palette("coolwarm", 5))

# %%
sns.palplot(sns.color_palette("copper", 5))

# %%
sns.palplot(sns.color_palette("crest", 5))

# %%
sns.palplot(sns.color_palette("cubehelix", 5))

# %%
sns.palplot(sns.color_palette("flag", 5))

# %%
sns.palplot(sns.color_palette("flare", 5))

# %%
sns.palplot(sns.color_palette("gist_earth", 5))

# %%
sns.palplot(sns.color_palette("gist_gray", 5))

# %%
sns.palplot(sns.color_palette("gist_heat", 5))

# %%
sns.palplot(sns.color_palette("gist_ncar", 5))

# %%
sns.palplot(sns.color_palette("gist_rainbow", 5))

# %%
sns.palplot(sns.color_palette("gist_stern", 5))

# %%
sns.palplot(sns.color_palette("gist_yarg", 5))

# %%
sns.palplot(sns.color_palette("gnuplot", 5))

# %%
sns.palplot(sns.color_palette("gnuplot2", 5))

# %%
sns.palplot(sns.color_palette("gray", 5))

# %%
sns.palplot(sns.color_palette("hot", 5))

# %%
sns.palplot(sns.color_palette("hsv", 5))

# %%
sns.palplot(sns.color_palette("icefire", 5))

# %%
sns.palplot(sns.color_palette("inferno", 5))

# %%
sns.palplot(sns.color_palette("jet_r", 5))

# %%
sns.palplot(sns.color_palette("magma", 5))

# %%
sns.palplot(sns.color_palette("mako", 5))

# %%
sns.palplot(sns.color_palette("nipy_spectral", 5))

# %%
sns.palplot(sns.color_palette("ocean", 5))

# %%
sns.palplot(sns.color_palette("pink", 5))

# %%
sns.palplot(sns.color_palette("plasma", 5))

# %%
sns.palplot(sns.color_palette("prism", 5))

# %%
sns.palplot(sns.color_palette("rainbow", 5))

# %%
sns.palplot(sns.color_palette("rocket", 5))

# %%
sns.palplot(sns.color_palette("seismic", 5))

# %%
sns.palplot(sns.color_palette("spring", 5))

# %%
sns.palplot(sns.color_palette("summer", 5))

# %%
sns.palplot(sns.color_palette("tab10", 5))

# %%
sns.palplot(sns.color_palette("tab20", 5))

# %%
sns.palplot(sns.color_palette("tab20b", 5))

# %%
sns.palplot(sns.color_palette("tab20c", 5))

# %%
sns.palplot(sns.color_palette("turbo", 5))

# %%
sns.palplot(sns.color_palette("twilight", 5))

# %%
sns.palplot(sns.color_palette("twilight_shifted", 5))

# %%
sns.palplot(sns.color_palette("viridis", 5))

# %%
sns.palplot(sns.color_palette("vlag", 5))

# %%
sns.palplot(sns.color_palette("winter", 5))

# %% [markdown]
# ## Palettes: 20 colors

# %% [markdown]
# ### Diverging (расходящиеся)

# %% [markdown]
# Расходящиеся палитры используются там, где интересны как большие, так и маленькие значения, с чётко определенной, нейтральной серединой. Например, это может быть тепловая карта доходов и расходов или реальной температурой чего-либо. Основными критериями хорошей расходящейся палитры является наличие всего двух цветов, желательно, без красного и зеленого, т.к. они трудно воспринимаются вместе, и одинаковое смещение оттенков с обеих сторон.
#
# Источник: [PyProg Управление цветом](https://pyprog.pro/sns/sns_12_color_setting.html "PyProg Управление цветом")

# %% [markdown]
# Важно: деление палитр по разделам условное. В конце "расходящихся" и "последовательных" палитр есть неоднозначные варианты.

# %%
sns.palplot(sns.color_palette("PiYG", 20))

# %%
sns.palplot(sns.color_palette("PRGn", 20))

# %%
sns.palplot(sns.color_palette("BrBG", 20))

# %%
sns.palplot(sns.color_palette("PuOr", 20))

# %%
sns.palplot(sns.color_palette("RdBu", 20))

# %%
sns.palplot(sns.color_palette("RdGy", 20))

# %%
sns.palplot(sns.color_palette("bwr", 20))

# %%
sns.palplot(sns.color_palette("vlag", 20))

# %%
sns.palplot(sns.color_palette("coolwarm", 20))

# %%
sns.palplot(sns.color_palette("twilight_shifted", 20))

# %%
sns.palplot(sns.color_palette("seismic", 20))

# %%
sns.palplot(sns.color_palette("brg", 20))

# %%
sns.palplot(sns.color_palette("twilight", 20))

# %%
sns.palplot(sns.color_palette("icefire", 20))

# %%
sns.palplot(sns.color_palette("RdYlBu", 20))

# %%
sns.palplot(sns.color_palette("Spectral", 20))

# %%
sns.palplot(sns.color_palette("RdYlGn", 20))

# %%
sns.palplot(sns.color_palette("rainbow", 20))

# %%
sns.palplot(sns.color_palette("turbo", 20))

# %%
sns.palplot(sns.color_palette("jet_r", 20))

# %% [markdown]
# ### Sequential (последовательные)

# %% [markdown]
# Последовательные палитры лучше всего подходят для визуализации плавного изменения числовых значений, чаще всего это двумерные гистограммы, тепловые карты или kde-графики. Здесь важно использовать цветовые палитры из одного цвета, с плавным изменением яркости и насыщенности. Это связано с тем, что если между значениями в данных есть очень большие разрывы, то использование нескольких цветов не позволит это заметить.
#
# Источник: [PyProg Управление цветом](https://pyprog.pro/sns/sns_12_color_setting.html "PyProg Управление цветом")

# %% [markdown]
# В Matplotlib, что бы сменить направление изменения насыщенности и яркости нужно к названию палитры добавить суффикс '_r':
#
# - sns.color_palette('Greens', 10)    # прямое направление
# - sns.color_palette('Greens_r', 10)     # обратное направление
#
#
# В Seaborn есть еще один суффикс - '_d', который позволяет "затемнить" последовательну палитру:
#
# - sns.color_palette('Greens_d', 10)

# %%
sns.palplot(sns.color_palette("Reds", 20))

# %%
sns.palplot(sns.color_palette("Oranges", 20))

# %%
sns.palplot(sns.color_palette("Greens", 20))

# %%
sns.palplot(sns.color_palette("Blues", 20))

# %%
sns.palplot(sns.color_palette("Purples", 20))

# %%
sns.palplot(sns.color_palette("Greys", 20))

# %%
sns.palplot(sns.color_palette("RdPu", 20))

# %%
sns.palplot(sns.color_palette("OrRd", 20))

# %%
sns.palplot(sns.color_palette("YlOrRd", 20))

# %%
sns.palplot(sns.color_palette("YlOrBr", 20))

# %%
sns.palplot(sns.color_palette("YlGn", 20))

# %%
sns.palplot(sns.color_palette("YlGnBu", 20))

# %%
sns.palplot(sns.color_palette("GnBu", 20))

# %%
sns.palplot(sns.color_palette("BuGn", 20))

# %%
sns.palplot(sns.color_palette("BuPu", 20))

# %%
sns.palplot(sns.color_palette("PuRd", 20))

# %%
sns.palplot(sns.color_palette("PuBu", 20))

# %%
sns.palplot(sns.color_palette("PuBuGn", 20))

# %%
sns.palplot(sns.color_palette("binary", 20))

# %%
sns.palplot(sns.color_palette("gist_yarg", 20))

# %%
sns.palplot(sns.color_palette("gray", 20))

# %%
sns.palplot(sns.color_palette("gist_gray", 20))

# %%
sns.palplot(sns.color_palette("bone", 20))

# %%
sns.palplot(sns.color_palette("ocean", 20))

# %%
sns.palplot(sns.color_palette("mako", 20))

# %%
sns.palplot(sns.color_palette("viridis", 20))

# %%
sns.palplot(sns.color_palette("cividis", 20))

# %%
sns.palplot(sns.color_palette("pink", 20))

# %%
sns.palplot(sns.color_palette("flare", 20))

# %%
sns.palplot(sns.color_palette("crest", 20))

# %%
sns.palplot(sns.color_palette("gist_earth", 20))

# %%
sns.palplot(sns.color_palette("cubehelix", 20))

# %%
sns.palplot(sns.color_palette("copper", 20))

# %%
sns.palplot(sns.color_palette("summer", 20))

# %%
sns.palplot(sns.color_palette("autumn", 20))

# %%
sns.palplot(sns.color_palette("winter", 20))

# %%
sns.palplot(sns.color_palette("spring", 20))

# %%
sns.palplot(sns.color_palette("Wistia", 20))

# %%
sns.palplot(sns.color_palette("cool", 20))

# %%
sns.palplot(sns.color_palette("rocket", 20))

# %%
sns.palplot(sns.color_palette("gist_heat", 20))

# %%
sns.palplot(sns.color_palette("afmhot", 20))

# %%
sns.palplot(sns.color_palette("hot", 20))

# %%
sns.palplot(sns.color_palette("inferno", 20))

# %%
sns.palplot(sns.color_palette("magma", 20))

# %%
sns.palplot(sns.color_palette("plasma", 20))

# %%
sns.palplot(sns.color_palette("CMRmap", 20))

# %%
sns.palplot(sns.color_palette("gnuplot", 20))

# %%
sns.palplot(sns.color_palette("gnuplot2", 20))

# %%
sns.palplot(sns.color_palette("gist_stern", 20))

# %%
sns.palplot(sns.color_palette("hsv", 20))

# %%
sns.palplot(sns.color_palette("gist_rainbow", 20))

# %%
sns.palplot(sns.color_palette("gist_ncar", 20))

# %%
sns.palplot(sns.color_palette("nipy_spectral", 20))

# %% [markdown]
# ### Qualitative (категориальные)

# %% [markdown]
# Категориальные палитры лучше всего подходят для визуализации тяжелых элементов, таких как boxplot или violinplot. В этом случае необходимо просто различать элементы поэтому используются палитры из небольшого количества цветов.
#
# Источник: [PyProg Управление цветом](https://pyprog.pro/sns/sns_12_color_setting.html "PyProg Управление цветом")

# %%
sns.palplot(sns.color_palette("Accent", 20))

# %%
sns.palplot(sns.color_palette("Dark2", 20))

# %%
sns.palplot(sns.color_palette("Paired", 20))

# %%
sns.palplot(sns.color_palette("Pastel1", 20))

# %%
sns.palplot(sns.color_palette("Pastel2", 20))

# %%
sns.palplot(sns.color_palette("Set1", 20))

# %%
sns.palplot(sns.color_palette("Set2", 20))

# %%
sns.palplot(sns.color_palette("Set3", 20))

# %%
sns.palplot(sns.color_palette("flag", 20))

# %%
sns.palplot(sns.color_palette("prism", 20))

# %%
sns.palplot(sns.color_palette("tab10", 20))

# %%
sns.palplot(sns.color_palette("tab20", 20))

# %%
sns.palplot(sns.color_palette("tab20b", 20))

# %%
sns.palplot(sns.color_palette("tab20c", 20))

# %% [markdown]
# ## How to extract individual colors

# %%
sns.palplot(sns.color_palette("gist_earth_r", 20))

# %% [markdown]
# Например нам нужно 14 цветов, уберём из этих 20 первые 2 цвета (слишком бледные) и последние 4 (слишком тёмные). Выведем на экран значения цветов, скопируем их и создадим свою палитру, убрав лишнее:

# %%
print(sns.color_palette("gist_earth_r", 20).as_hex())
# Out:
# ['#f0dad7', '#e2c1b3', '#d5b194', '#c7a676', '#bea863', '#b9b35f', '#aab35c', '#96ae58', '#82a954', '#6ba44f', '#4e9c47', '#419552', '#3c8e61', '#368770', '#30817e', '#286d7d', '#20597b', '#184179', '#102777', '#080b75']

# %%
my_palette=['#d5b194', '#c7a676', '#bea863', '#b9b35f', '#aab35c', '#96ae58', '#82a954', 
            '#6ba44f', '#4e9c47', '#419552', '#3c8e61', '#368770', '#30817e', '#286d7d']

# %% [markdown]
# ## Types of palettes

# %% [markdown]
# ![2022-11-21_07-47-34.png](attachment:2022-11-21_07-47-34.png)

# %% [markdown]
# Условно цветовые палитры можно разделить на три категории:
#
# - Diverging - расходящиеся палитры - подходят для визуализации числовых данных с категориальными границами;
# - Sequential - последовательные палитры - используются для визуализации числовых данных;
# - Qualitative - категориальные (или качественные) палитры - лучше всего подходят для визуализации категориальных данных.
#
# [PyProg Управление цветом](https://pyprog.pro/sns/sns_12_color_setting.html "PyProg Управление цветом")

# %% [markdown]
# ### hls_palette & husl_palette

# %% [markdown]
# Если "тяжелых" элементов слишком много, т.е. очень много категорий в данных, то самый простой способ их различать, не выделяя ни одной из них - это использовать круговые палитры. Круговая палитра - это палитра цвета в которой меняются в циклическом пространстве цветов с сохранением яркости и насыщенности. Самый простой способ создания таких палитр - это применение пространства hls:

# %%
sns.palplot(sns.color_palette('hls', 15))

# %% [markdown]
# Если нужно контролировать яркость и насыщенность цветов, то можно воспользоваться функцией hls_palette():

# %%
sns.palplot(sns.hls_palette(15, l=0.4, s=0.9))

# %% [markdown]
# Однако, использование hls все же допускает выделение элементов, так как для нашей зрительной системы желтый цвет кажется более ярким чем синий. Если нужно гарантированно "сгладить" все элементы, то лучше воспользоваться системой husl (HSLuv):

# %%
sns.palplot(sns.color_palette('husl', 15))

# %% [markdown]
# Как видите, насыщенность и яркость в данной палитре выглядит гораздо равномернее. Если нужен более гибкий доступ к этой системе цветов, то можно воспользоваться функцией husl_palette():

# %%
sns.palplot(sns.husl_palette(15, l=0.4, s=0.9))

# %% [markdown]
# ### cubehelix_palette

# %% [markdown]
# В случаях, очень большого количества градаций, черно белой печати или дальтонизма, последовательные палитры могут передавть числовую информацию не вполной мере. Что бы избежать этого, можно воспользоваться цветовой системой cubehelix с линейным изменением яркости и оттенка. В Matplotlib имеется собственная палитра cubehelix:

# %%
sns.palplot(sns.color_palette('cubehelix', 15))

# %% [markdown]
# В Seaborn данная палитра изменена так, что оттенок меняется гораздо слабее интенсивности:

# %%
sns.palplot(sns.cubehelix_palette(15))

# %% [markdown]
# Функция cubehelix_palette() позволяет настраивать данную палитру, например, можно задать начальный цвет (значения из интервала [0; 3]) и поворот в системе оттенков:

# %%
sns.palplot(sns.cubehelix_palette(15, start=2, rot=0.5))

# %% [markdown]
# Можно даже контролировать, то насколько яркими и темными будут крайние значения палитры и поворот самой палитры:

# %%
sns.palplot(sns.cubehelix_palette(15, start=2, rot=0.5, dark=0.05, light=0.7, reverse=True))

# %% [markdown]
# ### ColorBrewer

# %% [markdown]
# Инструмент [ColorBrewer](https://colorbrewer2.org/#type=sequential&scheme=BuGn&n=7 "ColorBrewer") является хорошим источником палитр, но помимо этого он так же дает некоторые рекомендации по поводу того, какая палитра для какой ситуации лучше всего подходит.

# %% [markdown]
# ## Separate colors and their names in Seaborn

# %% [markdown]
# ![2022-11-21_07-49-18.png](attachment:2022-11-21_07-49-18.png)

# %% [markdown]
# ## Types of charts

# %% [markdown]
# ![6a00d8341bfd2e53ef0111683a7591970c.jpg](attachment:6a00d8341bfd2e53ef0111683a7591970c.jpg)

# %% [markdown]
# Ещё больше интересного в моём телеграм-канале [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
